# %%
# %matplotlib inline

# %%
import seaborn as sns
import pandas as pd
# Out:
# C:\Users\diaobao\Anaconda2\envs\bio-ipy\lib\site-packages\matplotlib\__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# If you want to see what parameters are included, you can just call the function with no arguments,

# %%
sns.axes_style()
# Out:
# {'axes.axisbelow': True,
#  'axes.edgecolor': '.15',
#  'axes.facecolor': 'white',
#  'axes.grid': False,
#  'axes.labelcolor': '.15',
#  'axes.linewidth': 1.25,
#  'figure.facecolor': (1, 1, 1, 0),
#  'font.family': [u'sans-serif'],
#  'font.sans-serif': [u'Arial',
#   u'Liberation Sans',
#   u'Bitstream Vera Sans',
#   u'sans-serif'],
#  'grid.color': '.8',
#  'grid.linestyle': u'-',
#  'image.cmap': u'Greys',
#  'legend.frameon': False,
#  'legend.numpoints': 1,
#  'legend.scatterpoints': 1,
#  'lines.solid_capstyle': u'round',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'xtick.direction': u'out',
#  'xtick.major.size': 6.0,
#  'xtick.minor.size': 3.0,
#  'ytick.color': '.15',
#  'ytick.direction': u'out',
#  'ytick.major.size': 6.0,
#  'ytick.minor.size': 3.0}

# %% [markdown]
# Styling figures with axes_style() and set_style().There are five preset seaborn themes: darkgrid, whitegrid, dark, white, and ticks

# %%
sns.set(style="ticks", palette="deep", color_codes=True)

# %%
tips = sns.load_dataset("tips")

# %% [markdown]
# The four preset contexts, in order of relative size, are paper, notebook, talk, and poster. The notebook style is the default

# %%
sns.set_context("notebook")

# %% [markdown]
# When the ticks don’t cover the whole range of the axis, the trim parameter will limit the range of the surviving spines.
# sns.despine(offset=10, trim=True);
# You can also control which spines are removed with additional arguments to despine():
# sns.despine(left=True)

# %%
sns.violinplot(x="total_bill", y="day", hue="sex", data=tips, scale="width", split=True, inner="box", palette={"Male": sns.xkcd_rgb["peach"], "Female": sns.xkcd_rgb["baby blue"]})
sns.despine()
